# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

pd.set_option('max_column', None)
pumpkins = pd.read_csv('../data/US-pumpkins.csv')

# %%
pumpkins.shape
# Out:
# (1757, 26)

# %%
print(pumpkins.columns.values)
# Out:
# ['City Name' 'Type' 'Package' 'Variety' 'Sub Variety' 'Grade' 'Date'
#  'Low Price' 'High Price' 'Mostly Low' 'Mostly High' 'Origin'
#  'Origin District' 'Item Size' 'Color' 'Environment' 'Unit of Sale'
#  'Quality' 'Condition' 'Appearance' 'Storage' 'Crop' 'Repack' 'Trans Mode'
#  'Unnamed: 24' 'Unnamed: 25']

# %%
pumpkins.head(5)
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade     Date  \
# 0  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN  4/29/17
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN   5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
#
#    Low Price  High Price  Mostly Low  Mostly High    Origin Origin District  \
# 0      270.0       280.0       270.0        280.0  MARYLAND             NaN
# 1      270.0       280.0       270.0        280.0  MARYLAND             NaN
# 2      160.0       160.0       160.0        160.0  DELAWARE             NaN
# 3      160.0       160.0       160.0        160.0  VIRGINIA             NaN
# 4       90.0       100.0        90.0        100.0  MARYLAND             NaN
#
#   Item Size   Color  Environment Unit of Sale  Quality  Condition  Appearance  \
# 0       lge     NaN          NaN          NaN      NaN        NaN         NaN
# 1       lge     NaN          NaN          NaN      NaN        NaN         NaN
# 2       med  ORANGE          NaN          NaN      NaN        NaN         NaN
# 3       med  ORANGE          NaN          NaN      NaN        NaN         NaN
# 4       lge  ORANGE          NaN          NaN      NaN        NaN         NaN
#
#    Storage  Crop Repack  Trans Mode  Unnamed: 24 Unnamed: 25
# 0      NaN   NaN      E         NaN          NaN         NaN
# 1      NaN   NaN      E         NaN          NaN         NaN
# 2      NaN   NaN      N         NaN          NaN         NaN
# 3      NaN   NaN      N         NaN          NaN         NaN
# 4      NaN   NaN      N         NaN          NaN         NaN

# %%
pumpkins.isna().sum()
# Out:
# City Name             0
# Type               1712
# Package               0
# Variety               5
# Sub Variety        1461
# Grade              1757
# Date                  0
# Low Price             0
# High Price            0
# Mostly Low          103
# Mostly High         103
# Origin                3
# Origin District    1626
# Item Size           279
# Color               616
# Environment        1757
# Unit of Sale       1595
# Quality            1757
# Condition          1757
# Appearance         1757
# Storage            1757
# Crop               1757
# Repack                0
# Trans Mode         1757
# Unnamed: 24        1757
# Unnamed: 25        1654
# dtype: int64

# %%
pumpkins = pumpkins[pumpkins['Color'].notna()]
pumpkins.dropna(how='all', axis=1, inplace=True)
pumpkins.head(5)
# Out:
#    City Name Type       Package      Variety Sub Variety      Date  Low Price  \
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN   9/24/16      160.0
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN   9/24/16      160.0
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN   11/5/16       90.0
# 5  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN  11/12/16       90.0
# 6  BALTIMORE  NaN  36 inch bins  HOWDEN TYPE         NaN   9/24/16      160.0
#
#    High Price  Mostly Low  Mostly High    Origin Origin District Item Size  \
# 2       160.0       160.0        160.0  DELAWARE             NaN       med
# 3       160.0       160.0        160.0  VIRGINIA             NaN       med
# 4       100.0        90.0        100.0  MARYLAND             NaN       lge
# 5       100.0        90.0        100.0  MARYLAND             NaN       lge
# 6       170.0       160.0        170.0  MARYLAND             NaN       med
#
#     Color Unit of Sale Repack Unnamed: 25
# 2  ORANGE          NaN      N         NaN
# 3  ORANGE          NaN      N         NaN
# 4  ORANGE          NaN      N         NaN
# 5  ORANGE          NaN      N         NaN
# 6  ORANGE          NaN      N         NaN

# %%
pumpkins.rename( columns={'Unnamed: 25':'some column'}, inplace=True )

# %%
pumpkins.shape
# Out:
# (1141, 17)

# %%
pumpkins.isna().sum()
# Out:
# City Name             0
# Type               1140
# Package               0
# Variety               0
# Sub Variety         909
# Date                  0
# Low Price             0
# High Price            0
# Mostly Low           89
# Mostly High          89
# Origin                0
# Origin District    1035
# Item Size           150
# Color                 0
# Unit of Sale       1017
# Repack                0
# some column        1052
# dtype: int64

# %%
for col in pumpkins:
    print(col, ": ", pumpkins[col].unique())
# Out:
# City Name :  ['BALTIMORE' 'ATLANTA' 'BOSTON' 'CHICAGO' 'COLUMBIA' 'LOS ANGELES'
#  'NEW YORK' 'DETROIT' 'DALLAS' 'MIAMI' 'SAN FRANCISCO' 'PHILADELPHIA'
#  'ST. LOUIS']
# Type :  [nan 'Organic']
# Package :  ['24 inch bins' '36 inch bins' '1 1/9 bushel cartons' '1/2 bushel cartons'
#  '1 1/9 bushel crates' 'bushel cartons' 'bins' '35 lb cartons'
#  '50 lb sacks' '40 lb cartons' 'bushel baskets' '22 lb cartons']
# Variety :  ['HOWDEN TYPE' 'PIE TYPE' 'BIG MACK TYPE' 'MINIATURE' 'CINDERELLA'
#  'FAIRYTALE' 'BLUE TYPE' 'KNUCKLE HEAD' 'HOWDEN WHITE TYPE']
# Sub Variety :  [nan 'FLAT TYPE' 'ROUND TYPE']
# Date :  ['9/24/16' '11/5/16' '11/12/16' '10/1/16' '10/8/16' '10/15/16' '10/22/16'
#  '10/29/16' '9/16/17' '9/23/17' '9/30/17' '11/19/16' '11/26/16' '12/3/16'
#  '12/10/16' '9/2/17' '9/9/17' '11/29/14' '9/26/16' '9/27/16' '9/28/16'
#  '9/29/16' '9/30/16']
# Low Price :  [160.    90.   150.   140.   100.   130.   120.    15.    18.    17.
#   16.   200.   190.    50.    40.   145.   180.   170.   195.   175.
#  260.   135.   250.   220.   240.   300.   270.    20.    60.   125.
#  165.   225.   185.    19.    21.   400.    28.    30.    85.    80.
#  235.   275.     0.5   24.5   24.    12.   115.    35.   155.   110.
#  440.    25.    45.    48.    46.   105.    15.75  12.5   13.75  10.75
#   16.75  14.75]
# High Price :  [160.   100.   170.   130.   120.    15.    18.    17.    18.5   16.
#  200.    60.    50.   154.75 150.   145.   140.   180.   225.   285.
#  175.   220.   300.   280.   240.   190.    24.   135.   125.   165.
#  250.   185.    19.    21.   400.    28.    30.    90.   235.   375.
#    0.5    0.85  24.5  265.    20.    12.   115.    35.   155.   440.
#   22.    48.    45.    55.   105.   275.    15.75  12.5   16.75  14.75
#   10.75]
# Mostly Low :  [160.   90.  150.  140.  100.  130.  120.   15.   18.   17.   16.  200.
#  190.   50.   40.  145.  165.  225.  180.  175.  135.  220.  195.  170.
#  210.  185.  285.  275.  270.  250.  260.  240.  300.  280.   24.   60.
#  125.   19.   21.  400.   28.   30.   85.   80.  235.    0.5  24.5  20.
#   12.  105.  117.  115.   35.  155.  110.  440.   25.   45.   48.   46.
#    nan]
# Mostly High :  [160.   100.   170.   130.    15.    18.    17.    18.5   16.   200.
#   60.    50.   154.75 150.   145.   140.   165.   225.   190.   180.
#  155.   185.   175.   220.   195.   285.   275.   270.   260.   210.
#  255.   240.   300.    24.   135.   125.   120.   250.    19.    21.
#  400.    28.    30.    90.   235.   375.     0.5    0.85  24.5  265.
#   20.    12.   110.   119.   115.    35.   440.    22.    48.    45.
#   55.      nan]
# Origin :  ['DELAWARE' 'VIRGINIA' 'MARYLAND' 'PENNSYLVANIA' 'OHIO' 'MICHIGAN'
#  'ALABAMA' 'CANADA' 'TENNESSEE' 'MASSACHUSETTS' 'VERMONT' 'NEW YORK'
#  'ILLINOIS' 'NORTH CAROLINA' 'CALIFORNIA' 'NEW JERSEY' 'TEXAS' 'MEXICO']
# Origin District :  [nan 'QUEBEC' 'ONTARIO' 'CENTRAL SAN JOAQUIN VALLEY CALIFORNIA'
#  'ORANGE COUNTY NEW YORK' 'WESTERN SECTION']
# Item Size :  ['med' 'lge' 'sml' 'xlge' 'med-lge' nan 'jbo' 'exjbo']
# Color :  ['ORANGE' 'WHITE' 'STRIPED']
# Unit of Sale :  [nan 'EACH' 'PER BIN' 'PER LB']
# Repack :  ['N']
# some column :  [nan 'LOWER.' 'STEADY.' 'ABOUT STEADY.' 'MINIATURE LOWER, OTHERS STEADY.']

# %%
X = pumpkins.loc[ : , pumpkins.columns != 'Color']
y = pumpkins['Color']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#           City Name Type               Package            Variety Sub Variety  \
# 406          BOSTON  NaN          24 inch bins           PIE TYPE         NaN
# 390          BOSTON  NaN  1 1/9 bushel cartons           PIE TYPE         NaN
# 1462  SAN FRANCISCO  NaN          36 inch bins        HOWDEN TYPE         NaN
# 1036       COLUMBIA  NaN    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 608         CHICAGO  NaN          36 inch bins  HOWDEN WHITE TYPE         NaN
#
#           Date  Low Price  High Price  Mostly Low  Mostly High         Origin  \
# 406    10/8/16      200.0       200.0       200.0        200.0       MICHIGAN
# 390    10/8/16       15.0        16.0        15.0         15.0  MASSACHUSETTS
# 1462   9/23/17      120.0       120.0       120.0        120.0     CALIFORNIA
# 1036  10/29/16       18.0        18.0        18.0         18.0   PENNSYLVANIA
# 608   10/15/16      150.0       150.0       150.0        150.0       ILLINOIS
#
#      Origin District Item Size Unit of Sale Repack some column
# 406              NaN       sml          NaN      N         NaN
# 390              NaN       sml          NaN      N         NaN
# 1462             NaN       med          NaN      N         NaN
# 1036             NaN       sml          NaN      N         NaN
# 608              NaN       lge          NaN      N         NaN

# %%
categorical_features = ['City Name', 'Type', 'Package', 'Variety', 'Sub Variety', 'Date', 'Origin', 'Origin District', 'Item Size', 'Unit of Sale', 'Repack', 'some column']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy="constant")),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('logregressor', LogisticRegression(solver="liblinear"))])

pipeline.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-6cebe1e1b56e> in <module>
#      12                            ('logregressor', LogisticRegression(solver="liblinear"))])
#      13
# ---> 14 pipeline.fit(X_train, y_train)
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     881                         ensure_2d=False, dtype=None)
#     882     else:
# --> 883         y = column_or_1d(y, warn=True)
#     884         _assert_all_finite(y)
#     885     if y_numeric and y.dtype.kind == 'O':
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     919         return np.ravel(y)
#     920
# --> 921     raise ValueError(
#     922         "y should be a 1d array, "
#     923         "got an array of shape {} instead.".format(shape))
#
# ValueError: y should be a 1d array, got an array of shape (912, 4) instead.

# %%
predictions = pipeline.predict(X_test)

# %%
print(classification_report(y_test, predictions))
print('Predicted labels: ', predictions)
print('Accuracy: ', accuracy_score(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#       ORANGE       0.88      0.97      0.92       180
#      STRIPED       0.00      0.00      0.00         3
#        WHITE       0.81      0.54      0.65        46
#
#     accuracy                           0.87       229
#    macro avg       0.56      0.50      0.52       229
# weighted avg       0.85      0.87      0.85       229
#
# Predicted labels:  ['ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'WHITE' 'WHITE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'WHITE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'WHITE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'WHITE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'WHITE' 'ORANGE' 'WHITE' 'WHITE' 'ORANGE' 'ORANGE'
#  'ORANGE' 'ORANGE' 'ORANGE' 'ORANGE' 'WHITE']
# Accuracy:  0.868995633187773
# /Users/aibek/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aibek/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aibek/opt/anaconda3/envs/microsoft_ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[174,   0,   6],
#        [  3,   0,   0],
#        [ 21,   0,  25]])
